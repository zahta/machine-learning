# %% [markdown]
# ## Assignment Set 1 by [Zahra Taheri](https://github.com/zata213/Applied_Machine_Learning_S20_Assignments) for Applied Machine Learning (Spring 2020) Course at Data Science Center, SBU

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': np.random.randn(500)}
data['b'] = data['a'] + 10 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
df = pd.DataFrame(np.random.randn(10, 4)) 
print(df)

j=1.23
for i in range(80000000):
  j+=j    

print("\n-> Execution Time = %s in Seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3
# 0  0.048797  0.728791 -0.422406  1.537746
# 1  0.243051  0.059964 -1.346411  0.851362
# 2  1.993114  0.386482 -0.652296  0.243042
# 3 -0.173675  0.071125 -0.844876  0.322367
# 4 -1.045530  0.392410  0.392780  1.868690
# 5 -0.715704  0.426316 -0.190296 -0.417408
# 6  0.543159  0.014564  0.537784  1.924941
# 7 -1.404682 -0.278451  1.763054 -0.406325
# 8  0.370391 -1.195373 -0.367369 -0.285428
# 9 -0.118508 -0.222301 -0.734136 -0.467568
#
# -> Execution Time = 9.503824472427368 in Seconds <-

# %%
np.random.seed(1)
n=100
x=np.random.randn(n) # A random 1xn array that can be reproduced by np.random.seed(1)
y=x*np.random.randn(n)

colors=np.random.rand(n)
plt.plot(np.unique(x),np.poly1d(np.polyfit(x,y,1))(np.unique(x)))

plt.scatter(x,y,c=colors,alpha=0.5)
plt.show()
